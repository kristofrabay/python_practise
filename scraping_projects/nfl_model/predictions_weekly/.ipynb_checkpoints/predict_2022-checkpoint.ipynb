# %% [markdown]
# ## Start by setting week number
# #### Wait for ESPN data update until at least Wednesday morning, but run latest by Thursday night
#
# https://www.espn.com/nfl/stats/team/_/stat/total/season/2022/seasontype/2

# %%
SET_WEEK = 1
week_name = 'week_' + str(SET_WEEK)
print(week_name)
# Out:
# week_1

# %%
from scrapers.scrape_2022 import get_2022_data
import pandas as pd
import numpy as np
import pickle

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Models

# %%
logit = '../modeling/logit.pkl'
rf = '../modeling/rf.pkl'
gbm = '../modeling/gbm.pkl'
lgb = '../modeling/lgb.pkl'
catboost = '../modeling/catboost.pkl'

with open(logit, 'rb') as file:
    LOGIT = pickle.load(file)

with open(rf, 'rb') as file:
    RF = pickle.load(file)
    
with open(gbm, 'rb') as file:
    GBM = pickle.load(file)
    
with open(lgb, 'rb') as file:
    LGB = pickle.load(file)
    
with open(catboost, 'rb') as file:
    CATBOOST= pickle.load(file)

# %% [markdown]
# ### 2022 data

# %%
# %%time

X = get_2022_data()

# from boruta elimination method:
keep_cols = ['offense_points_per_game',
             'offense_downs_Fourth Downs_PCT',
             'offense_passing_AVG',
             'offense_passing_YDS/G',
             'offense_passing_RTG',
             'offense_receiving_AVG',
             'defense_points_per_game',
             'defense_passing_AVG',
             'defense_receiving_AVG',
             'defense_rushing_YDS/G',
             'defense_passing_SYL_per_game',
             'offense_downs_Third Downs_ATT_per_game',
             'defense_downs_Third Downs_ATT_per_game',
             'defense_downs_First Downs_penalty_ratio',
             'offense_passing_TD_per_game',
             'defense_rushing_TD_per_game',
             'defense_pass_TD_per_rush_TD',
             'offense_pass_TD_to_INT']

X = X[['Team', 'games_played', 'season'] + keep_cols].copy()

X.head(2)
# Out:
# Wall time: 17.7 s
#                   Team  games_played  season  offense_points_per_game  \
# 0   Kansas City Chiefs           1.0    2022                     20.0
# 1  Philadelphia Eagles           1.0    2022                     44.0
#
#    offense_downs_Fourth Downs_PCT  offense_passing_AVG  offense_passing_YDS/G  \
# 0                             0.0                  9.2                  360.0
# 1                            33.3                  7.6                  239.0
#
#    offense_passing_RTG  offense_receiving_AVG  defense_points_per_game  ...  \
# 0                144.2                   12.0                     24.0  ...
# 1                 80.6                   13.5                     27.0  ...
#
#    defense_receiving_AVG  defense_rushing_YDS/G  defense_passing_SYL_per_game  \
# 0                    8.5                  103.0                          26.0
# 1                   10.2                  181.0                          10.0
#
#    offense_downs_Third Downs_ATT_per_game  \
# 0                                    15.0
# 1                                    16.0
#
#    defense_downs_Third Downs_ATT_per_game  \
# 0                                    13.0
# 1                                    10.0
#
#    defense_downs_First Downs_penalty_ratio  offense_passing_TD_per_game  \
# 0                                 0.055556                          5.0
# 1                                 0.043478                          0.0
#
#    defense_rushing_TD_per_game  defense_pass_TD_per_rush_TD  \
# 0                          1.0                     2.000000
# 1                          3.0                     0.666667
#
#    offense_pass_TD_to_INT
# 0                     inf
# 1                     NaN
#
# [2 rows x 21 columns]

# %%
print(X.shape)
# Out:
# (31, 21)

# %%
X.fillna(0, inplace = True)
X.replace([np.inf, -np.inf], 0, inplace=True)

# %%
X['games_played'].unique().tolist()
# Out:
# [1.0, 0.0]

# %%
# X[X['games_played'] == 8]

# %%
predictions = X[['Team', 'season']].copy()
predictions['week_marker'] = week_name

predictions['pred_logit'] = LOGIT.predict_proba(X.drop(['Team', 'games_played', 'season'], 1))[:,1]
predictions['pred_rf'] = RF.predict_proba(X.drop(['Team', 'games_played', 'season'], 1))[:,1]
predictions['pred_gbm'] = GBM.predict_proba(X.drop(['Team', 'games_played', 'season'], 1))[:,1]
predictions['pred_lgb'] = LGB.predict_proba(X.drop(['Team', 'games_played', 'season'], 1))[:,1]
predictions['pred_catboost'] = CATBOOST.predict_proba(X.drop(['Team', 'games_played', 'season'], 1))[:,1]
predictions['pred_mean'] = (predictions['pred_logit'] + predictions['pred_rf'] + predictions['pred_gbm'] + predictions['pred_lgb'] + predictions['pred_catboost']) / 5
predictions['pred_opt_combo'] = (predictions['pred_logit'] + 7*predictions['pred_catboost']) / 8

predictions.sort_values('pred_opt_combo', ascending = False, inplace = True)
predictions.head(3)
# Out:
#                     Team  season week_marker  pred_logit   pred_rf  pred_gbm  \
# 4          Buffalo Bills    2022      week_1    0.887279  0.304545  0.192810
# 15  Tampa Bay Buccaneers    2022      week_1    0.973871  0.182806  0.130139
# 5      Minnesota Vikings    2022      week_1    0.847803  0.340240  0.193529
#
#     pred_lgb  pred_catboost  pred_mean  pred_opt_combo
# 4   0.321591       0.413192   0.423883        0.472453
# 15  0.289598       0.380873   0.391457        0.454997
# 5   0.334050       0.395330   0.422191        0.451889

# %%
predictions.to_csv('weekly_runs_2022/' + week_name + '.csv', index = False)

# %% [markdown]
# ### Check weekly run

# %%
predictions
# Out:
#                      Team  season week_marker  pred_logit   pred_rf  pred_gbm  \
# 4           Buffalo Bills    2022      week_1    0.887279  0.304545  0.192810
# 15   Tampa Bay Buccaneers    2022      week_1    0.973871  0.182806  0.130139
# 5       Minnesota Vikings    2022      week_1    0.847803  0.340240  0.193529
# 29                      0    2022      week_1    0.996975  0.088395  0.075048
# 7   Washington Commanders    2022      week_1    0.803238  0.189637  0.105720
# 11          New York Jets    2022      week_1    0.758179  0.109171  0.088789
# 2      Cincinnati Bengals    2022      week_1    0.218882  0.131086  0.113461
# 14   Los Angeles Chargers    2022      week_1    0.017210  0.230660  0.143224
# 17    San Francisco 49ers    2022      week_1    0.295960  0.088240  0.058244
# 13       Cleveland Browns    2022      week_1    0.206334  0.122906  0.085755
# 22       Baltimore Ravens    2022      week_1    0.024772  0.177090  0.096251
# 6         New York Giants    2022      week_1    0.000005  0.112562  0.077153
# 0      Kansas City Chiefs    2022      week_1    0.003432  0.254155  0.145151
# 18      Las Vegas Raiders    2022      week_1    0.015171  0.089032  0.058229

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import networkx as nx
from pyvis.network import Network

import re
from nltk.util import ngrams
from nltk.collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer

def plot_conversation_network(from_to_data = from_to_counts, edge_divider = 125,
                              k = 6, size = (16, 9), node_size_power = 0.85):
    
    np.random.seed(12)
    nodes = from_to_data.groupby('speaker')['weight'].sum()

    G = nx.from_pandas_edgelist(from_to_data, source = 'speaker', target = 'speaking_to', 
                                edge_attr = 'weight', create_using = nx.Graph())

    node_sizes = nodes[[i for i in G.nodes]]

    line_widths = [i['weight'] / edge_divider for i in dict(G.edges).values()]
    labels = {i:i for i in dict(G.nodes).keys()}

    plt.figure(figsize = size) 

    pos = nx.fruchterman_reingold_layout(G, k = k)
    nx.draw_networkx_nodes(G, pos = pos, node_size = np.power(node_sizes, node_size_power), 
                           node_color = 'lightgray', edgecolors = 'gray', alpha = 1) 
    nx.draw_networkx_edges(G, pos = pos, width = line_widths, edge_color = 'black', alpha = 1/2)
    nx.draw_networkx_labels(G, pos = pos, font_size = 11)

    plt.box(False)
    plt.show()
    
# good styles:
# 1. fruchterman_reingold_layout
# 2. circular_layout
# 3. spring_layout


def ngram_plots(ngram_number = 1, row_spacing = .03, col_spacing = .1, width = 950, col_wrap = 3):
    
    ngram_col_name = 'ngram_' + str(ngram_number)
    
    fig = px.bar(grams_dfs_N[ngram_number].groupby('speaker').head(10).sort_values(['speaker', 'count']), 'count', ngram_col_name, facet_col='speaker', 
             facet_col_wrap=col_wrap, facet_row_spacing=row_spacing, facet_col_spacing=col_spacing,
              title = 'Top ngrams (' + str(ngram_number) + ') by characters',
              labels = {ngram_col_name : ''}, width = width, height = 1650)
    fig.update_xaxes(showticklabels = True, matches = None)
    fig.update_yaxes(showticklabels=True, matches = None, tickfont = {'size' : 10})
    fig.for_each_annotation(lambda a: a.update(text = a.text.split('=')[-1]))
    fig.update_layout(showlegend = False)
    fig.show()
    
    
def plot_tfidf_data(data = tfidf_data, row_spacing = .03, col_spacing = .1, width = 950, col_wrap = 3):
    
    fig = px.bar(data, 'score', 'word', facet_col='speaker', 
             facet_col_wrap=col_wrap, facet_row_spacing=row_spacing, facet_col_spacing=col_spacing,
              title = 'Top characters most personal words (TF-IDF)',
              labels = {'score' : 'Tf-Idf value', 'word' : ''}, width = width, height = 1650)
    fig.update_xaxes(showticklabels = True, matches = None)
    fig.update_yaxes(showticklabels=True, matches = None, tickfont = {'size' : 10})
    fig.for_each_annotation(lambda a: a.update(text = a.text.split('=')[-1]))
    fig.update_layout(showlegend = False)
    fig.show()

# %%
data = pd.read_csv('../../data/transcripts_cleaned.csv')
data.head(3)
# Out:
#    season  episode  title  scene  speaker  \
# 0       1        1  Pilot      1  Michael
# 1       1        1  Pilot      1      Jim
# 2       1        1  Pilot      1  Michael
#
#                                                 line  \
# 0  All right Jim. Your quarterlies look very good...
# 1         Oh, I told you. I couldn't close it. So...
# 2  So you've come to the master for guidance? Is ...
#
#                                              cleaned  \
# 0  all right jim your quarterlies look very good ...
# 1              oh i told you i could not close it so
# 2  so you have come to the master for guidance is...
#
#                                    cleaned_sw_rem
# 0  right jim quarterlies look good things library
# 1                                      told close
# 2              master guidance saying grasshopper

# %% [markdown]
# ### Line count

# %%
top_lines = data['speaker'].value_counts().head(23)
top_characters = top_lines.index

# %%
med_line_count = data[data['speaker'].isin(top_characters)].groupby(['speaker', 'season']).agg({'line' : 'count'}).reset_index().groupby('speaker').agg({'line' : 'median'}).reset_index().rename(columns = {'line' : 'median_lines_by_season'})
med_line_count.loc[med_line_count['speaker'] == 'Robert California', 'median_lines_by_season'] = 394
med_line_count.set_index('speaker', inplace = True)

# %%
line_count_data = pd.concat([top_lines, med_line_count], 1).reset_index().rename(columns = {'speaker' : 'total_lines', 'index' : 'speaker'})

# %%
line_count_by_season = data[data['speaker'].isin(top_characters)].pivot_table(index = 'speaker', columns = ['season'], values = 'line', aggfunc = 'count')
line_count_by_season = line_count_by_season.fillna(0).astype(int).reset_index()

# %%
line_count_by_season_all = data.pivot_table(index = 'speaker', columns = ['season'], values = 'line', aggfunc = 'count')
line_count_by_season_all = line_count_by_season_all.fillna(0).astype(int).reset_index()
line_count_by_season_all = line_count_by_season_all.melt('speaker', value_name = 'lines')\
                                                    .sort_values(['season', 'lines'], ascending = [True, False])\
                                                    .groupby('season').head(10).reset_index(drop = True)

# %% [markdown]
# ### To and From lines

# %% [markdown]
# Most likely if a scene length is 1, then it is a camerashot. Then there is no back-n-forth, so it is not a conversation. When filling in the 'speaking-to' column, these exceptions will have to be marked as NaN. Also, at the end of every scene, the last 'speaking-to' is NaN. This can be imputed to the previous person who was talking.

# %%
data['speaking_to'] = data.groupby('scene')['speaker'].shift(-1)

# %%
data = data.merge(data.groupby('scene')['speaker'].nth(-2), left_on = 'scene', right_index = True, how = 'left').rename(columns = {'speaker_x' : 'speaker', 'speaker_y' : 'before_last_to_talk'})
data['speaking_to'].fillna(data['before_last_to_talk'], inplace = True)
data.drop('before_last_to_talk', 1, inplace = True)
data.loc[data['speaker'] == data['speaking_to'], 'speaking_to'] = np.nan

# %%
from_to_counts = data[['speaker', 'speaking_to']].value_counts().reset_index().rename(columns = {0 : 'line_count'})
from_to_counts = from_to_counts[(from_to_counts['speaker'].isin(top_characters)) &
                                (from_to_counts['speaking_to'].isin(top_characters))]

# %%
from_to_counts_by_season = data[['season', 'speaker', 'speaking_to']].value_counts().reset_index().rename(columns = {0 : 'line_count'})
from_to_counts_by_season.sort_values(['season', 'line_count'], ascending = [True, False], inplace = True)
from_to_counts_by_season = from_to_counts_by_season[(from_to_counts_by_season['speaker'].isin(top_characters)) &
                                                     (from_to_counts_by_season['speaking_to'].isin(top_characters))]

# %% [markdown]
# ### Word count

# %%
lines = data[['speaker', 'cleaned_sw_rem']].copy()
lines = lines[lines['speaker'].isin(top_characters)]
lines.dropna(inplace = True)

# %%
documents = lines['speaker'].unique().tolist()
grams_dfs_N = {}
Ns = [1, 2, 3]

for N in Ns:
    
    ngram_col_name = 'ngram_' + str(N)
    grams_dfs = {}

    for speaker in documents:

        transcript = re.compile('\s+').sub(' ', ' '.join(lines[lines['speaker'] == speaker]['cleaned_sw_rem']))
        count_grams = Counter(ngrams(transcript.split(' '), N))
        count_grams_df = pd.DataFrame.from_dict(count_grams, orient = 'index')\
                                     .reset_index().sort_values(0, ascending = False).reset_index(drop = True)\
                                     .rename(columns = {'index' : ngram_col_name, 0 : 'count'})
        if N != 1:
            
            count_grams_df['check_repetitions'] = count_grams_df[ngram_col_name].apply(lambda x: 1 if len(set(x)) == 1 else 0)
            count_grams_df = count_grams_df[count_grams_df['check_repetitions'] == 0]
            count_grams_df.drop('check_repetitions', 1, inplace = True)
            count_grams_df.reset_index(drop = True, inplace = True)
            
        count_grams_df[ngram_col_name] = count_grams_df[ngram_col_name].apply(lambda x: ' '.join(x))

        grams_dfs[speaker] = count_grams_df
        
    grams_dfs = pd.concat(grams_dfs, axis = 0, ignore_index = False)\
                    .reset_index()\
                    .drop('level_1', 1)\
                    .rename(columns = {'level_0' : 'speaker'})
    grams_dfs_N[N] = grams_dfs

# %%
print(len(grams_dfs_speaker) == len(top_characters))
# Out:
# True

# %% [markdown]
# ### TF-IDF

# %%
documents = lines['speaker'].unique().tolist()
words = []

for speaker in documents:
    words.append(' '.join(lines[lines['speaker'] == speaker]['cleaned_sw_rem']))
    
vectorizer = TfidfVectorizer(max_df=.5, min_df = 1, norm = None)
transformed_documents = vectorizer.fit_transform(words)

transformed_documents_as_array = transformed_documents.toarray()
len(transformed_documents_as_array) == len(documents)
# Out:
# True

# %%
# https://programminghistorian.org/en/lessons/analyzing-documents-with-tfidf#how-the-algorithm-works

tfidf_by_speakers = []

for counter, doc in enumerate(transformed_documents_as_array):
    
    speaker = documents[counter]    
    score_col_name = 'score' 
    tf_idf_tuples = list(zip(vectorizer.get_feature_names(), doc))
    one_doc_as_df = pd.DataFrame.from_records(tf_idf_tuples, columns=['word', 'score']).sort_values(by='score', ascending=False).reset_index(drop=True).head(10)
    one_doc_as_df['speaker'] = speaker
    
    tfidf_by_speakers.append(one_doc_as_df)
    
tfidf_data = pd.concat(tfidf_by_speakers, axis = 0)
tfidf_data.sort_values(['speaker', 'score'], ascending = [True, False], inplace = True)
#tfidf_data.columns = tfidf_data.columns.droplevel()

# %% [markdown]
# ### Visualizations

# %% [markdown]
# #### Line count

# %%
fig, ax = plt.subplots(figsize = (12, 6))
sns.heatmap(line_count_by_season.set_index('speaker').replace(0, np.nan), 
            ax = ax, cmap = 'vlag', annot = True, fmt = '2g', center = 0)
plt.title('Line count by season of top characters\n')
plt.yticks(va = 'center', rotation = 0)
plt.show()

# %%
fig = px.bar(line_count_data.sort_values('median_lines_by_season'), 'median_lines_by_season', 'speaker',
              title = 'Average line count of top characters in their active seasons', 
              labels = {'speaker' : '', 'median_lines_by_season' : 'Median line number per season'},
              width = 750, height = 450)
fig.update_yaxes(tickfont = {'size' : 8})
fig.show()
# Out:
# <div>                            <div id="41adc387-44e8-47da-9805-0d461672dfbe" class="plotly-graph-div" style="height:450px; width:750px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("41adc387-44e8-47da-9805-0d461672dfbe")) {                    Plotly.newPlot(                        "41adc387-44e8-47da-9805-0d461672dfbe",                        [{"alignmentgroup":"True","hovertemplate":"Median line number per season=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[43,44,51,71,75,81,98,100,113,114,154,160,161,176,222,232,308,394,536,611,745,810,1565],"xaxis":"x","y":["Jan","David Wallace","Creed","Meredith","Stanley","Darryl","Gabe","Toby","Phyllis","Kelly","Ryan","Angela","Kevin","Oscar","Holly","Nellie Bertram","Erin","Robert California","Andy","Pam","Jim","Dwight","Michael"],"yaxis":"y"}],                        {"barmode":"relative","height":450,"legend":{"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"m ...

# %%
fig = px.bar(line_count_by_season_all.sort_values(['season', 'lines']), 'lines', 'speaker', facet_col='season', 
             facet_col_wrap=3, facet_row_spacing=.1, facet_col_spacing=.15,
              title = 'Top characters by line count in each season',
              labels = {'speaker' : ''}, width = 950, height = 605)
fig.update_xaxes(showticklabels = True, matches = None)
fig.update_yaxes(showticklabels=True, matches = None, tickfont = {'size' : 8})
#fig.for_each_annotation(lambda a: a.update(text = a.text.split('=')[-1]))
fig.update_layout(showlegend = False)
fig.show()
# Out:
# <div>                            <div id="124ba18d-c7e9-4d33-9d00-e8a7d4630701" class="plotly-graph-div" style="height:605px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("124ba18d-c7e9-4d33-9d00-e8a7d4630701")) {                    Plotly.newPlot(                        "124ba18d-c7e9-4d33-9d00-e8a7d4630701",                        [{"alignmentgroup":"True","hovertemplate":"season=1<br>lines=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[34,36,37,38,42,58,162,208,228,490],"xaxis":"x7","y":["Roy","Mr Brown","Ryan","Jan","Oscar","Katy","Pam","Dwight","Jim","Michael"],"yaxis":"y7"},{"alignmentgroup":"True","hovertemplate":"season=2<br>lines=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[92,103,117,132,163,234,611,745,815,1837],"xaxis":"x8","y":["Oscar","Toby","Kevin","Angela","Ryan","Jan","Pam","Jim","Dwight","Michael"],"yaxis":"y8"},{"alignmentgroup":"True","hovertemplate":"season=3<br>lines=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[140,161,196,255,275,300,593,680,810,1704],"xaxis":"x9","y":["Ryan","Kevin","Angela","Jan","Karen","Andy","Pam","Jim","Dwight","Michael"],"yaxis":"y9"},{"alignmentgroup":"True","hovertemplate":"season=4<br>lines=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[111,125,167,184,184,201,437,474,574,1378],"xaxis":"x4","y":["Toby","Kevin","Angela","Andy","Jan","Ryan","Pam","Dwight","Jim","Michael"],"yaxis":"y4"},{"alignmentgroup":"True","hovertemplate":"season=5<br>lines=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[169,195,206,221,222,477,696,837,1027,2063],"xaxis":"x5","y":["Phyllis","Oscar","Angela","Charles","Holly","Andy","Pam","Jim","Dwight","Michael"],"yaxis":"y5"},{"alignmentgroup":"True","hovertemplate":"season=6<br>lines=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[138,138,176,227,295,536,705,809,922,1976],"xaxis":"x6","y":["Jo Bennett","Phyllis","Oscar","Kevin","Erin","Andy","Pam","Dwight","Jim","Michael"],"yaxis":"y6"},{"alignmentgroup":"True","hovertemplate":"season=7<br>lines=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[240,248,248,265,308,551,614,677,694,1426],"xaxis":"x","y":["Kevin","Darryl","DeAngelo","Holly","Erin","Andy","Pam","Jim","Dwight","Michael"],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"season=8<br>lines=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[222,228,232,298,394,396,456,803,897,1049],"xaxis":"x2","y":["Oscar","Kevin","Nellie Bertram","Darryl","Robert California","Erin","Pam","Jim","Dwight","Andy"],"yaxis":"y2"},{"alignmentgroup":"True","hovertemplate":"season=9<br>lines=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color": ...

# %% [markdown]
# #### From & To

# %%
from_to_counts.rename(columns = {'line_count' : 'weight'}, inplace = True)
from_to_counts_by_season.rename(columns = {'line_count' : 'weight'}, inplace = True)

# %%
plot_conversation_network()

# %%
for season in np.arange(1, 9 + 1):
    
    from_to_data = from_to_counts_by_season[from_to_counts_by_season['season'] == season].reset_index(drop = True).drop('season', 1)
    print('\nSeason ' + str(season))
    
    if season == 1:
        plot_conversation_network(from_to_data, size = (8, 6), node_size_power = 1, edge_divider = 7, k = 6)
        
    else:
        plot_conversation_network(from_to_data, size = (8, 6), node_size_power = 1, edge_divider = 25, k = 8)
# Out:
# Season 1
# Season 2
# Season 3
# Season 4
# Season 5
# Season 6
# Season 7
# Season 8
# Season 9

# %% [markdown]
# #### Word Count

# %%
ngram_plots()
# Out:
# <div>                            <div id="dad4bdff-cbfa-43bb-ba7c-d430a631c766" class="plotly-graph-div" style="height:1650px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dad4bdff-cbfa-43bb-ba7c-d430a631c766")) {                    Plotly.newPlot(                        "dad4bdff-cbfa-43bb-ba7c-d430a631c766",                        [{"alignmentgroup":"True","hovertemplate":"speaker=Andy<br>count=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[92,93,95,105,118,120,148,179,219,256],"xaxis":"x22","y":["need","little","mean","time","good","guys","really","well","right","yeah"],"yaxis":"y22"},{"alignmentgroup":"True","hovertemplate":"speaker=Angela<br>count=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[32,32,33,34,36,40,41,42,53,78],"xaxis":"x23","y":["pam","really","need","good","right","god","thank","kevin","well","dwight"],"yaxis":"y23"},{"alignmentgroup":"True","hovertemplate":"speaker=Creed<br>count=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[9,10,11,11,12,13,14,14,14,20],"xaxis":"x24","y":["love","yeah","guy","michael","pam","boss","right","really","creed","good"],"yaxis":"y24"},{"alignmentgroup":"True","hovertemplate":"speaker=Darryl<br>count=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[25,26,26,29,31,46,48,50,56,92],"xaxis":"x19","y":["andy","thing","need","look","say","mike","na","good","right","yeah"],"yaxis":"y19"},{"alignmentgroup":"True","hovertemplate":"speaker=David Wallace<br>count=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[17,17,19,20,21,22,25,32,33,77],"xaxis":"x20","y":["great","guys","right","good","andy","well","dwight","jim","yeah","michael"],"yaxis":"y20"},{"alignmentgroup":"True","hovertemplate":"speaker=Dwight<br>count=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[136,142,160,163,203,217,222,248,297,309],"xaxis":"x21","y":["say","time","really","need","well","yeah","good","right","michael","jim"],"yaxis":"y21"},{"alignmentgroup":"True","hovertemplate":"speaker=Erin<br>count=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[28,29,30,39,39,42,59,70,72,112],"xaxis":"x16","y":["gabe","pam","right","guys","michael","well","sorry","really","yeah","andy"],"yaxis":"y16"},{"alignmentgroup":"True","hovertemplate":"speaker=Gabe<br>count=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[12,13,13,13,19,20,21,23,24,25],"xaxis":"x17","y":["michael","need","say","guys","really","gabe","erin","right","yeah","well"],"yaxis":"y17"},{"alignmentgroup":"True","hovertemplate":"speaker=Holly<br>count=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":""," ...

# %%
ngram_plots(ngram_number=2, width = 1050, col_spacing=.15)
# Out:
# <div>                            <div id="5d37da48-6e03-40bd-94e0-a077451c8dc8" class="plotly-graph-div" style="height:1650px; width:1050px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d37da48-6e03-40bd-94e0-a077451c8dc8")) {                    Plotly.newPlot(                        "5d37da48-6e03-40bd-94e0-a077451c8dc8",                        [{"alignmentgroup":"True","hovertemplate":"speaker=Andy<br>count=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[8,9,9,9,10,15,15,16,19,20],"xaxis":"x22","y":["c amon","broccoli rob","big tuna","ladies gentlemen","little bit","nard dog","last night","yeah right","dunder mifflin","andy bernard"],"yaxis":"y22"},{"alignmentgroup":"True","hovertemplate":"speaker=Angela<br>count=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[3,3,3,3,3,4,6,7,7,7],"xaxis":"x23","y":["last week","davinci code","thank dwight","good luck","new york","bad cat","planning committee","party planning","mm hmm","parum pum"],"yaxis":"y23"},{"alignmentgroup":"True","hovertemplate":"speaker=Creed<br>count=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[2,2,2,2,2,2,2,3,5,7],"xaxis":"x24","y":["parking lot","biggest client","ever seen","couple bucks","dunder mifflin","big fella","wha wild","betty white","debbie brown","creed bratton"],"yaxis":"y24"},{"alignmentgroup":"True","hovertemplate":"speaker=Darryl<br>count=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[3,3,3,3,3,3,4,6,8,12],"xaxis":"x19","y":["big deal","good morning","blueberry muffin","yeah maybe","little girl","buy cookies","years ago","na da","dunder mifflin","da na"],"yaxis":"y19"},{"alignmentgroup":"True","hovertemplate":"speaker=David Wallace<br>count=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[2,3,3,3,3,3,3,4,4,6],"xaxis":"x20","y":["shop vac","three months","branch managers","new york","golden ticket","michael calling","dwight schrute","michael scott","suck yeah","dunder mifflin"],"yaxis":"y20"},{"alignmentgroup":"True","hovertemplate":"speaker=Dwight<br>count=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[12,13,13,13,13,16,26,32,37,56],"xaxis":"x21","y":["ever seen","schrute farms","paper company","david wallace","jim halpert","thank much","assistant regional","regional manager","dunder mifflin","dwight schrute"],"yaxis":"y21"},{"alignmentgroup":"True","hovertemplate":"speaker=Erin<br>count=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[4,4,4,4,4,5,5,6,7,11],"xaxis":"x16","y":["today andy","say hi","well andy","wanted say","task force","mifflin erin","really good","david wallace","andy coming","dunder mifflin"],"yaxis":"y16"},{"alignmentgroup":"True","hovertemplate":"speaker=Gabe<br>count=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offse ...

# %%
ngram_plots(ngram_number=3, row_spacing=.04, col_spacing=.2)
# Out:
# <div>                            <div id="c66039dd-121e-4af5-9e7b-c9ab7bf46476" class="plotly-graph-div" style="height:1650px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c66039dd-121e-4af5-9e7b-c9ab7bf46476")) {                    Plotly.newPlot(                        "c66039dd-121e-4af5-9e7b-c9ab7bf46476",                        [{"alignmentgroup":"True","hovertemplate":"speaker=Andy<br>count=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[3,3,3,3,3,3,3,3,3,3],"xaxis":"x22","y":["good old fashioned","ba na na","related michelle obama","fa la la","name andrew bernard","julia roberts goes","scranton white pages","andrew baines bernard","chemical handling protocols","little soy bean"],"yaxis":"y22"},{"alignmentgroup":"True","hovertemplate":"speaker=Angela<br>count=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[2,2,2,2,2,2,2,2,6,7],"xaxis":"x23","y":["pum pum played","dwight dwight give","supposed say launch","party supposed say","boyfriend state senator","certain events transpired","pum pum rum","pum rum pum","party planning committee","parum pum pum"],"yaxis":"y23"},{"alignmentgroup":"True","hovertemplate":"speaker=Creed<br>count=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[1,1,1,1,1,1,2,2,2,2],"xaxis":"x24","y":["work far reach","looking work far","working pirate code","good working pirate","breath good working","little breath good","tapas swiss miss","first b stand","creed bratton gets","wha wha wild"],"yaxis":"y24"},{"alignmentgroup":"True","hovertemplate":"speaker=Darryl<br>count=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[2,2,2,2,2,2,2,6,6,12],"xaxis":"x19","y":["faces around block","friendly faces around","yeah da na","chains causing pain","loose chains causing","break loose chains","block break loose","na na da","na da na","da na na"],"yaxis":"y19"},{"alignmentgroup":"True","hovertemplate":"speaker=David Wallace<br>count=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[1,1,2,2,2,2,2,2,2,3],"xaxis":"x20","y":["tell company buyer","company buyer board","reporting strong numbers","closing buffalo branch","suck suck yeah","making much money","dwight schrute dwight","golden ticket idea","suck yeah yeah","michael michael calling"],"yaxis":"y20"},{"alignmentgroup":"True","hovertemplate":"speaker=Dwight<br>count=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[4,4,4,4,4,5,5,6,7,26],"xaxis":"x21","y":["schrute dunder mifflin","may attention please","vp dwight vp","dunder mifflin scranton","schrute assistant regional","volunteer sheriff deputy","dwight k schrute","dwight schrute calling","hello dwight schrute","assistant regional manager"],"yaxis":"y21"},{"alignmentgroup":"True","hovertemplate":"speaker=Erin<br>count=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[ ...

# %% [markdown]
# #### TF-IDF

# %%
plot_tfidf_data(tfidf_data.sort_values(['speaker', 'score'], ascending = [True, True]))
# Out:
# <div>                            <div id="ef8e300c-9afb-46e4-867f-a5aae2a1b856" class="plotly-graph-div" style="height:1650px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ef8e300c-9afb-46e4-867f-a5aae2a1b856")) {                    Plotly.newPlot(                        "ef8e300c-9afb-46e4-867f-a5aae2a1b856",                        [{"alignmentgroup":"True","hovertemplate":"speaker=Andy<br>Tf-Idf value=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[30.79441541679836,31.364159848092005,33.40812105567847,33.50111363073666,36.95329850015803,38.18070977791825,56.5095501941046,59.078166112018444,60.26787939490107,145.0893392840211],"xaxis":"x22","y":["rob","treble","andrew","bum","flag","jessica","nard","la","cornell","tuna"],"yaxis":"y22"},{"alignmentgroup":"True","hovertemplate":"speaker=Angela<br>Tf-Idf value=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[12.317766166719343,13.392862087755795,13.545177444479563,16.021427017946177,16.879218636185097,24.394346548516,24.553580494218956,43.1121815835177,49.10126823623842,83.14492162535556],"xaxis":"x23","y":["ash","contract","charles","cats","committee","parum","phillip","sprinkles","senator","pum"],"yaxis":"y23"},{"alignmentgroup":"True","hovertemplate":"speaker=Creed<br>Tf-Idf value=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[7.158883083359672,7.705847753741535,8.375278407684165,8.375278407684165,9.238324625039507,9.904146265058632,10.454719949364002,13.939626599152001,17.42453324894,22.33407575382444],"xaxis":"x24","y":["bankruptcy","undo","cartwheel","devon","swiss","brown","betty","goo","debbie","bratton"],"yaxis":"y24"},{"alignmentgroup":"True","hovertemplate":"speaker=Darryl<br>Tf-Idf value=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[15.84663402409381,16.704060527839236,17.80158557549575,19.542316284596385,21.361902690594903,21.361902690594903,22.321436812926322,24.3810935856007,81.88729364728046,95.07980414456286],"xaxis":"x19","y":["nah","doo","philly","justine","dude","da","dot","val","mike","na"],"yaxis":"y19"},{"alignmentgroup":"True","hovertemplate":"speaker=David Wallace<br>Tf-Idf value=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[6.696431043877897,6.696431043877897,6.772588722239782,6.969813299576001,6.969813299576001,7.1206342301983,7.705847753741535,7.705847753741535,9.904146265058632,11.931471805599454],"xaxis":"x20","y":["comedy","buffalo","charles","arnie","vac","interview","vacuum","strengths","managers","alan"],"yaxis":"y20"},{"alignmentgroup":"True","hovertemplate":"speaker=Dwight<br>Tf-Idf value=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[47.725887222397816,48.26808263936653,48.26808263936653,53.94093427619075,57.44404833734006,58.74523239913598,58.74523239913598,73.45143010338386,96.53616527873307,199.37775844555242],"xaxis":"x21","y":["hay","father","beet","la","farm","idiot","regional","assistant","mose","schrute"],"yaxis":"y21"},{"a ...

# %% [markdown]
# #### WordClouds

# %%
# net = Network(notebook = True)
# net.from_nx(G)

# net.height = '450px'
# net.width = '850px'
# net.show('The Office - conversation network for top characters.html')

# %%
# ### ngrams other way around

# documents = lines['speaker'].unique().tolist()
# grams_dfs_speaker = {}
# Ns = [1, 2, 3]

# for speaker in documents:
    
#     transcript = re.compile('\s+').sub(' ', ' '.join(lines[lines['speaker'] == speaker]['cleaned_sw_rem']))
#     grams_dfs = {}
    
#     for N in Ns:
    
#         ngram_col_name = 'ngram_' + str(N)
        
#         count_grams = Counter(ngrams(transcript.split(' '), N))
#         count_grams_df = pd.DataFrame.from_dict(count_grams, orient = 'index')\
#                                      .reset_index().sort_values(0, ascending = False).reset_index(drop = True)\
#                                      .rename(columns = {'index' : ngram_col_name, 0 : 'count'})
#         count_grams_df[ngram_col_name] = count_grams_df[ngram_col_name].apply(lambda x: ' '.join(x))
#         grams_dfs[N] = count_grams_df
        
#     grams_dfs_speaker[speaker] = grams_dfs

# %%
# ### for polarity

# # TextBlob library provides a consistent API for NLP tasks such as POS Tagging, noun-phrase extraction and sentiment analysis
# from textblob import TextBlob

# # Defining a function to check the sentiment polarity (whether it is positive or negative or neutral)
# def polarity(text):
#     return TextBlob(text).sentiment.polarity

# office['polarity_score'] = office['line'].\
#    apply(lambda x : polarity(x))

# %%
### idea: vectorize / embed episodes, plot them via dimensionality reduction (tsne or pca) and 
#find most similar episodes based on text

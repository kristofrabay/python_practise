# %%
from scrapers.scrape_2021 import get_2021_data
import pandas as pd
import numpy as np
import pickle

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Models

# %%
rf = 'modeling/rf.pkl'
gbm = 'modeling/gbm.pkl'
lgb = 'modeling/lgb.pkl'
catboost = 'modeling/catboost.pkl'

with open(rf, 'rb') as file:
    RF = pickle.load(file)
    
with open(gbm, 'rb') as file:
    GBM = pickle.load(file)
    
with open(lgb, 'rb') as file:
    LGB = pickle.load(file)
    
with open(catboost, 'rb') as file:
    CATBOOST= pickle.load(file)

# %% [markdown]
# ### 2021 data

# %%
X = get_2021_data()

# from boruta elimination method:
keep_cols = ['offense_downs_Fourth Downs_PCT', 'offense_passing_AVG', 'offense_passing_YDS/G', 'offense_passing_RTG', 
             'offense_receiving_AVG', 'defense_passing_AVG', 'defense_passing_RTG', 'defense_receiving_AVG', 
             'punting_punts_per_game', 'defense_passing_SYL_per_game', 'offense_downs_Third Downs_ATT_per_game', 
             'defense_downs_Third Downs_ATT_per_game', 'defense_downs_Fourth Downs_ATT_per_game', 
             'defense_downs_First Downs_penalty_ratio', 'offense_passing_TD_per_game', 
             'offense_passing_INT_per_game', 'defense_passing_INT_per_game', 'offense_pass_TD_to_INT', 
             'defense_pass_TD_to_INT']

X = X[['Team', 'games_played', 'season'] + keep_cols].copy()

X.head(2)
# Out:
#                 Team  games_played  season  offense_downs_Fourth Downs_PCT  \
# 0  Las Vegas Raiders             1    2021                             0.0
# 1     Dallas Cowboys             1    2021                             0.0
#
#    offense_passing_AVG  offense_passing_YDS/G  offense_passing_RTG  \
# 0                  7.8                  409.0                 89.5
# 1                  6.9                  391.0                101.4
#
#    offense_receiving_AVG  defense_passing_AVG  defense_passing_RTG  ...  \
# 0                   12.8                  7.8                 98.6  ...
# 1                    9.6                  7.6                 97.0  ...
#
#    defense_passing_SYL_per_game  offense_downs_Third Downs_ATT_per_game  \
# 0                          18.0                                    15.0
# 1                           0.0                                    17.0
#
#    defense_downs_Third Downs_ATT_per_game  \
# 0                                    12.0
# 1                                    11.0
#
#    defense_downs_Fourth Downs_ATT_per_game  \
# 0                                      2.0
# 1                                      0.0
#
#    defense_downs_First Downs_penalty_ratio  offense_passing_TD_per_game  \
# 0                                 0.050000                          2.0
# 1                                 0.041667                          3.0
#
#    offense_passing_INT_per_game  defense_passing_INT_per_game  \
# 0                           1.0                           0.0
# 1                           1.0                           2.0
#
#    offense_pass_TD_to_INT  defense_pass_TD_to_INT
# 0                     2.0                     inf
# 1                     3.0                     2.0
#
# [2 rows x 22 columns]

# %%
X.fillna(0, inplace = True)
X.replace([np.inf, -np.inf], 0, inplace=True)

# %%
predictions = X[['Team', 'season']].copy()

predictions['pred_rf'] = RF.predict_proba(X.drop(['Team', 'games_played', 'season'], 1))[:,1]
predictions['pred_gbm'] = GBM.predict_proba(X.drop(['Team', 'games_played', 'season'], 1))[:,1]
predictions['pred_lgb'] = LGB.predict_proba(X.drop(['Team', 'games_played', 'season'], 1))[:,1]
predictions['pred_catboost'] = CATBOOST.predict_proba(X.drop(['Team', 'games_played', 'season'], 1))[:,1]
predictions['pred_mean'] = (predictions['pred_rf'] + predictions['pred_gbm'] + predictions['pred_lgb'] + predictions['pred_catboost']) / 4

predictions.head(3)
# Out:
#                    Team  season   pred_rf  pred_gbm  pred_lgb  pred_catboost  \
# 0     Las Vegas Raiders    2021  0.127655  0.079768  0.020914       0.262384
# 1        Dallas Cowboys    2021  0.123300  0.086218  0.018544       0.266005
# 2  Tampa Bay Buccaneers    2021  0.183365  0.170964  0.582563       0.282579
#
#    pred_mean
# 0   0.122680
# 1   0.123517
# 2   0.304868

# %%
# todo
# week marker so that after every week I can join them together column wise
# team - season - week1 - week2 - .... - week17

# %%
predictions.sort_values('pred_mean', ascending = False)
# Out:
#                     Team  season   pred_rf  pred_gbm  pred_lgb  pred_catboost  \
# 8       Los Angeles Rams    2021  0.338434  0.399649  0.830483       0.437053
# 9    San Francisco 49ers    2021  0.327355  0.405187  0.835084       0.406737
# 12     Arizona Cardinals    2021  0.343278  0.341233  0.339986       0.425780
# 5     Kansas City Chiefs    2021  0.248749  0.201192  0.500111       0.328736
# 2   Tampa Bay Buccaneers    2021  0.183365  0.170964  0.582563       0.282579
# 19      Seattle Seahawks    2021  0.290345  0.281733  0.074999       0.357663
# 22      Baltimore Ravens    2021  0.152085  0.163704  0.410286       0.270880
# 21    Cincinnati Bengals    2021  0.266793  0.233474  0.076343       0.336191
# 11        Houston Texans    2021  0.220041  0.164069  0.204398       0.316454
# 15   Philadelphia Eagles    2021  0.211790  0.168021  0.162648       0.329015
# 29    New Orleans Saints    2021  0.190139  0.146369  0.189339       0.337432
# 3      Minnesota Vikings    2021  0.197556  0.110619  0.060864       0.271690
# 10      Cleveland Browns    2021  0.177191  0.130505  0.020711       0.289992
# 13     Carolina Panthers    2021  0.141719  0.113394  0.097789       0.262007
# 27   Pittsburgh Steelers    2021  0.138883  0.119401  0.016579       0.274842
# 18       New York Giants    2021  0.110330  0.116897  0.017038       0.269079
# 1         Dallas Cowboys    2021  0.123300  0.086218  0.018544       0.266005
# 6   Jacksonville Jaguars    2021  0.120674  0.088719  0.006037       0.276207
# 0      Las Vegas Raiders    2021  0.127655  0.079768  0.020914       0.262384
# 26        Miami Dolphins    2021  0.099936  0.104343  0.017354       0.246341
# 16        Denver Broncos    2021  0.103614  0.061870  0.019133       0.267372
# 7          Detroit Lions    2021  0.099516  0.062898  0.005484       0.262573
# 14  New England Patriots    2021  0.073838  0.037165  0.045559       0.261389
# 31            Washington    2021  0.078314  0.062384  0.022764       0.249016
# 17         Buffalo Bills    2021  0.092000  0.065372  0.005742       0.248743
# 4   Los Angeles Chargers    2021  0.084200  0.062925  0.007402       0.256798
# 25     Green Bay Packers    2021  0.075139  0.058728  0.002761       0.244046
# 30       Atlanta Falcons    2021  0.068920  0.053929  0.001630       0.244456
# 20    Indianapolis Colts    2021  0.059946  0.040322  0.005636       0.250900
# 23         New York Jets    2021  0.056180  0.050099  0.002349       0.244050
# 24         Chicago Bears    2021  0.033621  0.035096  0.002625       0.245744
# 28      Tennessee Titans    2021  0.006005  0.024493  0.003788       0.219258
#
#     pred_mean
# 8    0.501405
# 9    0.493591
# 12   0.362569
# 5    0.319697
# 2    0.304868
# 19   0.251185
# 22   0.249239
# 21   0.228200
# 11   0.226241
# 15   0.217869
# 29   0.215820
# 3    0.160182
# 10   0.154599
# 13   0.153727
# 27   0.137426
# 18   0.128336
# 1    0.123517
# 6    0.122909
# 0    0.122680
# 26   0.116994
# 16   0.112997
# 7    0.107618
# 14   0.104488
# 31   0.103119
# 17   0.102964
# 4    0.102831
# 25   0.095169
# 30   0.092234
# 20   0.089201
# 23   0.088170
# 24   0.079272
# 28   0.063386

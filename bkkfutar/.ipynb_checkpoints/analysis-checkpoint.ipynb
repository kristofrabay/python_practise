# %%
from time import time, sleep
from datetime import date

from requests import get
import json

from multiprocessing.pool import ThreadPool as Pool

import haversine

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

def vehicle_df_creator(vehicles):
    
    vehicles_df = pd.DataFrame(vehicles['list']).drop(['stale', 'serviceDate', 'stopSequence', 'lastUpdateTime', 'status', 'congestionLevel', 'bearing', 'capacity', 'stopDistancePercent', 'wheelchairAccessible', 'style', 'deviated'], 1)
    vehicles_df = pd.concat([vehicles_df, pd.json_normalize(vehicles_df['location'])], 1)

    vehicles_df = vehicles_df.merge(routes, left_on = 'routeId', right_on = 'id', how = 'left')
    vehicles_df = vehicles_df.merge(stops_df[['id', 'name']], left_on = 'stopId', right_on = 'id', how = 'left')

    vehicles_df.drop(['location', 'type', 'routeId', 'stopId', 'id_x', 'id_y'], 1, inplace = True)
    vehicles_df.rename(columns = {'name' : 'Megálló'}, inplace = True)

    return vehicles_df

def plot_MOL_Bubi_dist():
    
    plt.figure()
    sns.displot(data = bikes_data, x = 'bikes', color = '#89bedc', height = 4, aspect = 2, bins = 15)

    plt.title('Elérhető MOL Bubi biciklik')
    plt.xlabel(None)
    plt.ylabel(None)
    plt.show()

def plot_MOL_bubi():
    
    bikes_data['size_for_plot'] = bikes_data['bikes'] + 1

    fig = px.scatter_mapbox(bikes_data, lat = 'lat', lon = 'lon', hover_name = 'name', 
                            #center = {"lat": 45.444617, "lon": 12.321308}, 
                            hover_data = ['name', 'bikes'],
                            title = 'MOL Bubi bicikli-állomások és szabad biciklik száma',
                            zoom = 10.9, size_max = 12, size = 'size_for_plot', 
                            mapbox_style = 'carto-positron', width = 750)
    fig.show()

    bikes_data.drop('size_for_plot', 1, inplace = True)
    
    
def plot_STOP_TYPES():
    
    order = megallok.groupby(['type'])['id'].count().sort_values(ascending  = False)
    
    plt.figure(figsize = (9, 4))
    ax = sns.countplot(y = 'type', data = megallok, color = '#89bedc', edgecolor = 'black', 
                       linewidth = 1/2, order = order.index)
    
    for p in ax.patches:
        ax.annotate("%.0f" % p.get_width(), xy=(p.get_width(), p.get_y()+p.get_height()/2),
            xytext=(5, 0), textcoords='offset points', ha="left", va="center")

    plt.title('Megálló típusok száma')
    plt.xlabel(None)
    plt.xlim(0, 4900)
    plt.ylabel(None)
    plt.show()
    
def plot_gyujtok_map():

    fig = px.scatter_mapbox(gyujto_stop_count, lat = 'lat', lon = 'lon', hover_name = 'name', 
                            #center = {"lat": 45.444617, "lon": 12.321308}, 
                            hover_data = ['name', 'stop_count'],
                            title = 'BKK gyűjtőállomások elhelyezkedése',
                            labels = {'name' : 'Név', 'stop_count' : 'Megállók száma'},
                            zoom = 10, size_max = 15, size = 'stop_count', 
                            mapbox_style = 'carto-positron', height = 650, width = 950)
    fig.show()
    
    
def plot_stops_map():
    
    megallok['size'] = 1

    fig = px.scatter_mapbox(megallok, lat = 'lat', lon = 'lon', hover_name = 'name',
                            hover_data = ['name', 'routeIds', 'direction'],
                            title = 'BKK megállók és állomások elhelyezkedése', size = 'size', size_max = 4,
                            labels = {'name' : 'Név', 'routeIds' : 'Útvonalak', 'direction' : 'Irány'},
                            zoom = 10, mapbox_style = 'carto-positron', height = 650, width = 950)
    fig.show()
    
    megallok.drop('size', 1, inplace = True)
    
    
def plot_ROUTE_TYPES():
    
    order = routes.groupby(['type'])['id'].count().sort_values(ascending  = False)
    
    plt.figure(figsize = (9, 4))
    ax = sns.countplot(y = 'type', data = routes, color = '#89bedc', edgecolor = 'black', 
                       linewidth = 1/2, order = order.index)
    
    for p in ax.patches:
        ax.annotate("%.0f" % p.get_width(), xy=(p.get_width(), p.get_y()+p.get_height()/2),
            xytext=(5, 0), textcoords='offset points', ha="left", va="center")

    plt.title('Útvonal típusok száma')
    plt.xlabel(None)
    plt.xlim(0, 350)
    plt.ylabel(None)
    plt.show()
    
    
def plot_CELALLOMAS():
    
    plt.figure(figsize = (9, 7))
    ax = sns.barplot(y = 'name', x = 'Útvonal végállomása', data = celallomasok, color = '#89bedc', edgecolor = 'black', 
                       linewidth = 1/2)
    
    for p in ax.patches:
        ax.annotate("%.0f" % p.get_width(), xy=(p.get_width(), p.get_y()+p.get_height()/2),
            xytext=(5, 0), textcoords='offset points', ha="left", va="center")

    plt.title('Vég- és kiinduló-állomások')
    plt.xlabel(None)
    plt.ylabel(None)
    plt.show()
    
def plot_vehicles_map():
    
    vehicles_df['size'] = 1

    fig = px.scatter_mapbox(vehicles_df, lat = 'lat', lon = 'lon', hover_name = 'shortName',
                            hover_data = ['shortName', 'licensePlate', 'model', 'vehicleRouteType', 'From', 'To', 'Megálló'],
                            title = 'Aktuális járművek', size = 'size', size_max = 4.5, 
                            labels = {'label' : 'Irány', 'licensePlate' : 'Rendszám', 'shortName' : 'Jármű száma',
                                      'model' : 'Típus', 'vehicleRouteType' : 'Járműtípus'},
                            color = 'vehicleRouteType', 
                            color_discrete_map = {'BUS' : 'blue', 'TRAM' : 'yellow', 'TROLLEYBUS' : 'red', 'SUBURBAN_RAILWAY' : 'green'},
                            zoom = 10, mapbox_style = 'carto-positron', height = 700, width = 1050)
    fig.show()
    
    vehicles_df.drop('size', 1, inplace = True)
    
    
def plot_VEHICLES_TYPES():
    
    order = vehicles_df['vehicleRouteType'].value_counts()
    
    plt.figure(figsize = (9, 4))
    ax = sns.countplot(y = 'vehicleRouteType', data = vehicles_df, color = '#89bedc', edgecolor = 'black', 
                       linewidth = 1/2, order = order.index)
    
    for p in ax.patches:
        ax.annotate("%.0f" % p.get_width(), xy=(p.get_width(), p.get_y()+p.get_height()/2),
            xytext=(5, 0), textcoords='offset points', ha="left", va="center")

    plt.title('Aktív járművek típusai')
    plt.xlabel(None)
    plt.xlim(0, vehicles_df['vehicleRouteType'].value_counts().max() + 75)
    plt.ylabel(None)
    plt.show()
    
    
def plot_BUS_TYPE(filter_type = 'ikarus'):
    
    vehicles_df_buses = vehicles_df[vehicles_df['vehicleRouteType'] == 'BUS'].copy()
    
    vehicles_df_buses[filter_type] = 0
    vehicles_df_buses.loc[vehicles_df_buses['model'].str.lower().str.contains(filter_type), filter_type] = 1
    vehicles_df_buses[filter_type] = vehicles_df_buses[filter_type].astype(str)
    
    vehicles_df_buses['size'] = 1

    fig = px.scatter_mapbox(vehicles_df_buses, lat = 'lat', lon = 'lon', hover_name = 'shortName',
                            hover_data = ['shortName', 'licensePlate', 'model', 'vehicleRouteType', 'From', 'To', 'Megálló'],
                            title = 'Busztípusok elhelyezkedése - ' + filter_type, size = 'size', size_max = 5, 
                            labels = {'label' : 'Irány', 'licensePlate' : 'Rendszám', 'shortName' : 'Jármű száma',
                                      'model' : 'Típus', 'vehicleRouteType' : 'Járműtípus'},
                            color = filter_type, 
                            color_discrete_map = {'0': 'lightgreen', '1' : 'brown'},
                            zoom = 10, mapbox_style = 'carto-positron', height = 650, width = 950)
    fig.show()
    
    vehicles_df_buses.drop('size', 1, inplace = True)
    
    
def get_trip_details(i):
    
    trip_link = 'https://futar.bkk.hu/api/query/v1/ws/otp/api/where/trip-details.json?tripId=' + i + '&date=' + today + '&key=bkk-web&version=4&appVersion=3.13.1-59506-4e2e9a7b&_=' + time_epoch
    trip_data = get(trip_link, headers = headers).json()
    
    if 'data' in trip_data.keys():
        trip_data = trip_data['data']
        
        trip_id = i
    
        if 'vehicle' in trip_data['entry'].keys():
            route_id = trip_data['entry']['vehicle']['routeId']    
        else:
            route_id = np.nan

        if 'stopSequence' in trip_data['entry']['stopTimes'][-1].keys():
            stops_num = trip_data['entry']['stopTimes'][-1]['stopSequence']
        else:
            stops_num = np.nan

        if 'shapeDistTraveled' in trip_data['entry']['stopTimes'][-1].keys():
            dist = trip_data['entry']['stopTimes'][-1]['shapeDistTraveled']
        else:
            dist = np.nan

        trip_dict = {'id' : route_id, 'tripId' : trip_id, 'num_of_stops' : stops_num, 'total_distance' : dist}

        return trip_dict
    
    else:
        pass 
    
    
BOXPLOT_PROPS = {
    'boxprops':{'edgecolor':'black', 'linewidth' : 1},
    'flierprops':{'markerfacecolor':'black', 'markeredgecolor':'darkgray', 'marker' : 'x'},
    'medianprops':{'color':'black', 'linewidth' : 1},
    'whiskerprops':{'color':'black', 'linewidth' : 1},
    'capprops':{'color':'black', 'linewidth' : 1}
}

def boxplot_sns(data, x, y):  
    
    order = data.groupby([x]).median().sort_values(y, ascending = False)

    plt.figure(figsize = (8, 4))
    sns.boxplot(data = data, y = x, x = y, color = 'blue', fliersize = 2, 
                **BOXPLOT_PROPS, order = order.index)
    plt.xlabel(y)
    plt.ylabel(None)
    plt.title('Járműtípusonkénti eloszlások\n')
    plt.show()

# %%
# %%time

headers = {'User-agent' : 'Mozilla/5.0 (Windows; U; Windows NT 5.1; de; rv:1.9.1.5) Gecko/20091102 Firefox/3.5.5'}

time_epoch = str(int(time()))
today = date.today().strftime("%Y%m%d")
lat = str(47.497913)
lon = str(19.040236)

vehicles_link = 'https://futar.bkk.hu/api/query/v1/ws/otp/api/where/vehicles-for-location.json?ifModifiedSince=' + time_epoch + '&lat=' + lat + '&latSpan=1&lon=' + lon + '&lonSpan=1&key=bkk-web&version=4&appVersion=3.13.1-59506-4e2e9a7b'
stops_link = 'https://futar.bkk.hu/api/query/v1/ws/otp/api/where/stops-for-location.json?lat=' + lat + '&latSpan=1&lon=' + lon + '&lonSpan=1&key=bkk-web&version=4&appVersion=3.13.1-59506-4e2e9a7b'
bikes_link = 'https://futar.bkk.hu/api/query/v1/ws/otp/api/where/bicycle-rental.json?key=bkk-web&version=4&appVersion=3.13.1-59506-4e2e9a7b'

stops = get(stops_link, headers = headers).json()['data']
bikes = get(bikes_link, headers = headers).json()['data']
sleep(1)
vehicles = get(vehicles_link, headers = headers).json()['data']
# Out:
# Wall time: 3.37 s

# %% [markdown]
# ### Bikes

# %%
bikes_data = pd.DataFrame(bikes['list'])
bikes_data.drop(['type', 'spaces'], 1, inplace = True)

# %%
plot_MOL_Bubi_dist()

# %%
plot_MOL_bubi()
# Out:
# <div>                            <div id="66ee1bbe-261c-452c-93a8-bf4e32afc716" class="plotly-graph-div" style="height:525px; width:750px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
fat - Kir\u00e1ly utca",1],["D\u00e9li p\u00e1lyaudvar",2],["J\u00f3zsef k\u00f6r\u00fat - Baross utca",2],["Wessel\u00e9nyi utca - S\u00edp utca",11],["Gyulai P\u00e1l utca - R\u00e1k\u00f3czi \u00fat",11],["\u00c1rp\u00e1d-h\u00edd M-J\u00f3zsef Attila Sz\u00ednh\u00e1z",8],["K\u00e9thly Anna t\u00e9r",5],["G\u00f6ncz \u00c1rp\u00e1d V\u00e1rosk\u00f6zpont",3],["N\u00e9pf\u00fcrd\u0151 utca - Dunavir\u00e1g utca",2],["Nagyv\u00e1rad t\u00e9r M - V\u00e1g\u00f3h\u00edd utca",4],["K\u0151farag\u00f3 utca - Vas utca",7],["Gogol utca - Pozsonyi utca",13],["T\u00f6m\u0151 utca - Ill\u00e9s utca",16],["P\u00e1rk\u00e1ny utca - Viza utca",6],["Astoria",13],["K\u00e1rp\u00e1t utca - Tisza utca",9],["Nagyv\u00e1rad t\u00e9r M - NKE",5],["R\u00e1k\u00f3czi t\u00e9r",4],["M\u00dcPA-Nemzeti Sz\u00ednh\u00e1z H",15],["Di\u00f3szegi S\u00e1muel utca - Eln\u00f6k utca",11],["Br\u00f3dy S\u00e1ndor utca - M\u00fazeum k\u00f6r\u00fat",0],["Szenes Iv\u00e1n t\u00e9r",5],["Ecseri \u00fat M",12],["P\u00f6tty\u00f6s utca M",11],["Ludovika t\u00e9r",2],["V\u00e1ci \u00fat - Victor Hugo utca",4],["Margitsziget",9],["J\u00e1szai Mari t\u00e9r",0],["Szent Istv\u00e1n park",10],["Budafoki \u00 ...

# %% [markdown]
# ### Stops

# %%
stops_df = pd.DataFrame.from_dict(stops['references']['stops'], orient = 'index').reset_index(drop = True)
stops_df.drop(['description', 'style', 'wheelchairBoarding'], 1, inplace = True)
stops_df.head(3)
# Out:
#              id        lat        lon          name      code direction  \
# 0  BKK_CSF00232  47.513817  19.033945  Margit körút  CSF00232
# 1  BKK_CSF00233  47.514609  19.033215  Apostol utca  CSF00233
# 2  BKK_CSF01563  47.483975  19.117162   Egészségház  CSF01563
#
#    locationType locationSubType routeIds stopColorType parentStationId type
# 0             1       stop-area       []         OTHER             NaN  NaN
# 1             1       stop-area       []         OTHER             NaN  NaN
# 2             1       stop-area       []         OTHER             NaN  NaN

# %%
gyujtok = stops_df[(stops_df['type'].isnull()) & 
                   (stops_df['stopColorType'] == 'OTHER') & 
                   (stops_df['locationSubType'].isin(['station', 'stop-area']))].copy()

# %%
megallok = stops_df[(stops_df['type'].notnull())].copy()
megallok.drop(['locationType', 'locationSubType'], 1, inplace = True)

# %%
plot_STOP_TYPES()

# %%
gyujto_stop_count = megallok.groupby('parentStationId')['id'].count().reset_index().rename(columns = {'id' : 'stop_count'})
gyujto_stop_count = gyujtok[['id', 'lat', 'lon', 'name']].merge(gyujto_stop_count, left_on = 'id', right_on = 'parentStationId').drop('parentStationId', 1)

# %%
plot_gyujtok_map()
# Out:
# <div>                            <div id="92022b1d-4aaa-4bb2-b51e-3daf8dfbfc21" class="plotly-graph-div" style="height:650px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
],["Komj\u00e1di B\u00e9la utca",2],["Zilah utca",1],["Detrek\u0151 utca",1],["Fenyves utca",2],["D\u00e9l-pesti aut\u00f3buszgar\u00e1zs",6],["T\u00fcske utca",1],["Bimb\u00f3 k\u00f6z",1],["G\u00e1bor \u00c1ron utca",1],["L\u00f3czy Lajos utca",1],["Hank\u00f3czy Jen\u0151 utca",1],["J\u00falia utca",2],["Vasas sportp\u00e1lya",2],["Vihorl\u00e1t \u00fat",2],["Harangvir\u00e1g utca",2],["Vir\u00e1g \u00e1rok",2],["Pasar\u00e9ti \u00fat",4],["Erzs\u00e9bet kir\u00e1lyn\u00e9 \u00fatja, alulj\u00e1r\u00f3",12],["Kisv\u00e1rda utca",2],["Nemzetk\u00f6zi Posta Kicser\u00e9l\u0151 K\u00f6zpont",1],["G\u0151zmozdony utca",1],["Miksz\u00e1th K\u00e1lm\u00e1n utca",2],["Solym\u00e1r, PEM\u00dc",2],["M\u00e9hecske utca",2],["Szakorvosi rendel\u0151int\u00e9zet",1],["Batthy\u00e1ny t\u00e9r",3],["Sz\u00e9ll K\u00e1lm\u00e1n t\u00e9r",26],["Magyar Aszfalt",4],["Kopp\u00e1ny utca",4],["F\u00f3t, Auchan \u00e1ruh\u00e1z",1],["\u00dajpest, \u00c1rp\u00e1d \u00fat haj\u00f3\u00e1llom\u00e1s",3],["Szigetcs\u00e9p, k\u00f6zs\u00e9gh\u00e1za",2],["Szugl\u00f3 utca / Cinkotai \u00fat",2],["Kom\u00f3csy utca",2],["Egressy \u00fat / Vez\u00e9r utca",4],["K\u00e1la utca",1],["\u00d6v utca / Egressy \u00fat",1],["R\u00e1kosmezei t\u00e9r",2],["Tur\u00e1n utca",2],["K\u00f6ves \u00fat / Szentl\u0151rinci \u00fat",2],["Mez\u0151k\u00f6v ...

# %%
plot_stops_map()

# %% [markdown]
# Calculate distance matrix - find farthest from all stop, closest stops, etc... For this use the 'Gyujok' data, not the actual stops

# %%
# %%time

distances = []

for i, row_i in gyujtok[gyujtok['id'].str.contains('CS')].iterrows():
    
    _from_id = row_i['id']
    _from_name = row_i['name']
    _from_coord = (row_i['lat'], row_i['lon'])
    
    for j, row_j in gyujtok[gyujtok['id'].str.contains('CS')].iterrows():
        
        _to_id = row_j['id']
        _to_name = row_j['name']
        _to_coord = (row_j['lat'], row_j['lon'])

        _dist = haversine.haversine(_from_coord, _to_coord, unit = haversine.Unit.METERS)

        _dist_dict = {'from_id' : _from_id, 'to_id' : _to_id,
                      'from_name' : _from_name,  'to_name' : _to_name, 'distance' : _dist}
        distances.append(_dist_dict)

# %%
# %%time

distances_df = pd.DataFrame(distances)
distances_df = distances_df[distances_df['distance'] != 0]
# distances.drop_duplicates('distance', inplace = True)

# %%
# distances_df.sort_values('distance', ascending = False)

# %% [markdown]
# 10 most farthest away from each other stops

# %%
farthest = distances_df.groupby('from_id')['distance'].min().sort_values().tail(10)

# %%
farthes_df = distances_df[(distances_df['from_id'].isin(farthest.index) )& 
                          (distances_df['distance'].isin(farthest.values))]

farthes_df = farthes_df.drop_duplicates('from_name')
farthes_df = farthes_df.drop_duplicates('distance')
farthes_df.sort_values('distance', ascending = False)

# %% [markdown]
# Farthest away stops:
#
#     - Monor - Vecsés: 13km
#     - Ráckeve - Angyalisziget: 2.7km

# %% [markdown]
# ### Routes

# %%
routes = pd.DataFrame.from_dict(stops['references']['routes'], orient = 'index')\
                     .reset_index(drop = True)\
                     .drop(['color', 'textColor', 'agencyId', 'iconDisplayType', 'iconDisplayText', 'style', 'sortOrder', 'bikesAllowed'], 1)

# potlok = routes[routes['id'].str.contains('VP|HP|MP')]
# potlok kiszurese
# routes = routes[~routes['id'].str.contains('VP|HP|MP')]

routes[['From', 'To']] = routes['description'].str.split('|', expand = True)

routes['To'] = routes['To'].str.strip()
routes['From'] = routes['From'].str.strip()

routes.drop(['description'], 1, inplace = True)

routes.head(3)
# Out:
#          id shortName type                     From                   To
# 0  BKK_9960       996  BUS  Cinkotai autóbuszgarázs     Újpest-központ M
# 1  BKK_9720       972  BUS   Törökbálint, Nyár utca  Móricz Zs. körtér M
# 2  BKK_9961      996A  BUS  Cinkotai autóbuszgarázs     Újpest-központ M

# %%
plot_ROUTE_TYPES()

# %%
celallomasok = pd.concat([routes['From'], routes['To']]).value_counts().reset_index().rename(columns = {'index' : 'name', 0 : 'Útvonal végállomása'}).head(25)
#celallomasok = stops_df[['name', 'lat', 'lon']].copy().drop_duplicates('name').merge(celallomasok, how = 'right')

# %%
plot_CELALLOMAS()

# %% [markdown]
# ### Vehicles - currently active on Map

# %%
vehicles_df = vehicle_df_creator(vehicles)
vehicles_df.head(3)
# Out:
#   vehicleId licensePlate                label                           model  \
# 0  BKK_3663       LOV871  Lajosmizsei sorompó  VanHool AG318 csuklós autóbusz
# 1  BKK_3665       LOV873        Boráros tér H  VanHool AG318 csuklós autóbusz
# 2  BKK_4511        V1441         Közvágóhíd H                    Ganz csuklós
#
#   vehicleRouteType          tripId        lat        lon shortName  \
# 0              BUS   BKK_C37690369  47.450134  19.160313        50
# 1              BUS  BKK_C365811857  47.417510  19.168152        54
# 2             TRAM  BKK_C377832558  47.469020  19.074812         2
#
#                          From             To       Megálló
# 0         Lajosmizsei sorompó     Határ út M           NaN
# 1  Péterimajor, Víztorony tér  Boráros tér H   Zöldségpiac
# 2             Jászai Mari tér   Közvágóhíd H  Közvágóhíd H

# %%
print('Aktív járművek:', vehicles_df.shape[0])
# Out:
# Aktív járművek: 1804

# %%
for i in vehicles_df['vehicleRouteType'].unique():
    print(i, '- Modellek\n')
    print(vehicles_df[vehicles_df['vehicleRouteType'] == i]['model'].value_counts())
    print('\n')
# Out:
# BUS - Modellek
#
# MERCEDES Conecto csuklós                    173
# MAN Lions City A21 (ArrivaBus)              139
# Volvo 7700A típusú csuklós autóbusz         122
# MB Citaro C2-S1 szóló autóbusz               75
# MB Citaro C2-S1-G csuklós autóbusz           72
# MAN A21 szóló (Volán, helyi, 3 ajtós)        72
# MERCEDES Citaro O 530 (BKV spec.)            65
# MERCEDES Conecto szóló (BKV)                 65
# Volvo szóló autóbusz                         52
# MERCEDES Conecto 2 szóló autóbusz            49
# VanHool A330 CNG típusú szóló autóbusz       40
# MERCEDES Conecto G 2 csuklós autóbusz        32
# VanHool  NewAG300 csuklós autóbusz           32
# Ikarus 280-as típusú autóbusz                29
# MERCEDES Conecto G 3 csuklós busz(Volán)     23
# Modulo M108d szóló autóbusz                  23
# Volvo hibrid szóló (BKV, 3 ajt) autóbusz     22
# MAN A21 szóló (Volán, helyközi, 2 ajtós)     21
# Volvo 7000A típusú csuklós autóbusz          20
# Ikarus 412-es típusú autóbusz                19
# Modulo M108d szóló autóbusz (rend.tart.)     18
# Mercedes-Benz eCitaro                        18
# MERCEDES O530 Citaro G csuklós autóbusz      17
# Ikarus 127V típusú szóló autóbusz            16
# Volvo 7900 csuklós (Volán, helyi, 4 ajt)     16
# VanHool AG318 csuklós autóbusz               16
# Ikarus 435-ös típusú autóbusz                14
# VOLVO-ALFABUSZ Civis 12 típ.szóló autób.     14
# Volvo hibrid szóló (BKV, 2 ajt) autóbusz     13
# Modulo M168d csuklós autóbusz                12
# Karsan ATAK típusú midi autóbusz             11
# MAN Lions City GL NG313 csuklós busz          9
# Ikarus 260-as típusú autóbusz                 8
# Solaris Urbino 10 típusú midi autóbusz        6
# Ikarus 405-ös típusú autóbusz                 4
# VanHool NewA330 szóló autóbusz                4
# MB515 minibusz                                4
# Renault ND Master mozgáskorl. száll.          4
# MODULO Medio C68E midi autóbusz               4
# Ikarus E91 típusú midi autóbusz               2
# Ikarus 405-ös alacsonypadlós autóbusz         2
# Volvo 7900 csuklós (Volán, helyk., 3 a )      1
# Ikarus 187V típusú csuklós autóbusz           1
# Name: model, dtype: int64
#
#
# TRAM - Modellek
#
# Tátra T5C5K                  86
# TW 6000                      62
# CAF 5 modulos szerelvény     46
# Siemens Combino              36
# KCSV7 Korszerűsített Ganz    25
# Ganz csuklós                 25
# CAF 9 modulos szerelvény     14
# Tátra T5C5                    6
# Name: model, dtype: int64
#
#
# SUBURBAN_RAILWAY - Modellek
#
# MXA-MXA      16
# MX-MX         3
# MXA           2
# MIXA-MIXA     2
# MXA-MXAK      1
# MX-MXA        1
# MXA-MX        1
# MX            1
# Name: model, dtype: int64
#
#
# TROLLEYBUS - Modellek
#
# GVM (Ikarus 280)típusú trolibusz         26
# SKODA-SOLARIS Trollino 12 szóló tr.      19
# SKODA-SOLARIS Trollino 18 csuklós tr.    14
# GANZ-SOLARIS Trollino 12 trolibusz       14
# 4. gen. SOLARIS Trollino 18 trolibusz    12
# 4. gen. SOLARIS Trollino 12 trolibusz     8
# Ikarus 435-ös típusú trolibusz            8
# MAN NGE152 típusú csuklós trolibusz       8
# Ikarus 412-es típusú trolibusz            7
# Ikarus 411-es típusú trolibusz            1
# Ikarus 412.81GT típusú trolibusz          1
# Name: model, dtype: int64

# %%
plot_VEHICLES_TYPES()

# %%
plot_vehicles_map()
# Out:
# <div>                            <div id="6478317b-ec1e-4d46-8492-366d883c853c" class="plotly-graph-div" style="height:700px; width:1050px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
VanHool AG318 csukl\u00f3s aut\u00f3busz","BUS","Bor\u00e1ros t\u00e9r H","Szentl\u0151rinci \u00fati ltp.","Szentl\u0151rinci \u00fati lak\u00f3telep"],["123A","LOV861","VanHool AG318 csukl\u00f3s aut\u00f3busz","BUS","Szentl\u0151rinci \u00fati ltp.","Hat\u00e1r \u00fat M","Szentl\u0151rinci \u00fati lak\u00f3telep"],["54","LOV858","VanHool AG318 csukl\u00f3s aut\u00f3busz","BUS","P\u00e9terimajor, V\u00edztorony t\u00e9r","Bor\u00e1ros t\u00e9r H","K\u00e9n utca H (Illatos \u00fat)"],["20E" ...

# %%
plot_BUS_TYPE('ikarus')
# Out:
# <div>                            <div id="e0df7ca1-22bc-4604-96be-12035a631fe1" class="plotly-graph-div" style="height:650px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0df7ca1-22bc-4604-96be-12035a631fe1")) {                    Plotly.newPlot(                        "e0df7ca1-22bc-4604-96be-12035a631fe1",                        [{"customdata":[["50","LOV871","VanHool AG318 csukl\u00f3s aut\u00f3busz","BUS","Lajosmizsei soromp\u00f3","Hat\u00e1r \u00fat M",null],["54","LOV873","VanHool AG318 csukl\u00f3s aut\u00f3busz","BUS","P\u00e9terimajor, V\u00edztorony t\u00e9r","Bor\u00e1ros t\u00e9r H","Z\u00f6lds\u00e9gpiac"],["123A","LOV868","VanHool AG318 csukl\u00f3s aut\u00f3busz","BUS","Szentl\u0151rinci \u00fati ltp.","Hat\u00e1r \u00fat M","M\u00e1rt\u00edrok \u00fatja / Hat\u00e1r \u00fat"],["54","LOV869","VanHool AG318 csukl\u00f3s aut\u00f3busz","BUS","P\u00e9terimajor, V\u00edztorony t\u00e9r","Bor\u00e1ros t\u00e9r H","Alvinc utca"],["23E","LOV874","VanHool AG318 csukl\u00f3s aut\u00f3busz","BUS","Bor\u00e1ros t\u00e9r H","Pesterzs\u00e9beti lak\u00f3telep","Haller utca / Soroks\u00e1ri \u00fat"],["23E","LOV875","VanHool AG318 csukl\u00f3s aut\u00f3busz","BUS","Bor\u00e1ros t\u00e9r H","Pesterzs\u00e9beti lak\u00f3telep","T\u00f6r\u00f6k Fl\u00f3ris utca"],[null,"LOV881","VanHool AG318 csukl\u00f3s aut\u00f3busz","BUS",null,null,null],["MOZG","LRV480","Renault ND Master mozg\u00e1skorl. sz\u00e1ll.","BUS","K\u00fcl\u00f6nj\u00e1rat","K\u00fcl\u00f6nj\u00e1rat",null],["223M","LOV878","VanHool AG318 csukl\u00f3s aut\u00f3busz","BUS","Bor\u00e1ros t\u00e9r H","Szentl\u0151rinci \u00fati ltp.","K\u00f6zv\u00e1g\u00f3h\u00edd H"],[null,"LRV481","Renault ND Master mozg\u00e1skorl. sz\u00e1ll.","BUS",null,null,null],["MOZG","LRV482","Renault ND Master mozg\u00e1skorl. sz\u00e1ll.","BUS","K\u00fcl\u00f6nj\u00e1rat","K\u00fcl\u00f6nj\u00e1rat",null],["298","MXJ003","MB515 minibusz","BUS","Zimonyi utca","R\u00e1koscsaba vas\u00fat\u00e1llom\u00e1s","Csaba vez\u00e9r t\u00e9r"],["133E","MUT781","MB Citaro C2-S1-G csukl\u00f3s aut\u00f3busz","BUS","\u00dajpalota, Ny\u00edrpalota \u00fat","Nagyt\u00e9t\u00e9ny, Erd\u00e9lyi utca","Ur\u00e1nia"],["54","LOV853","VanHool AG318 csukl\u00f3s aut\u00f3busz","BUS","P\u00e9terimajor, V\u00edztorony t\u00e9r","Bor\u00e1ros t\u00e9r H","K\u00fcls\u0151 Mester utca"],["123","LOV855","VanHool AG318 csukl\u00f3s aut\u00f3busz","BUS","Soroks\u00e1r, IKEA \u00e1ruh\u00e1z","Hat\u00e1r \u00fat M","Soroks\u00e1r, Auchan \u00e1ruh\u00e1z"],["223M","LOV860","VanHool AG318 csukl\u00f3s aut\u00f3busz","BUS","Bor\u00e1ros t\u00e9r H","Szentl\u0151rinci \u00fati ltp.","Szentl\u0151rinci \u00fati lak\u00f3telep"],["123A","LOV861","VanHool AG318 csukl\u00f3s aut\u00f3busz","BUS","Szentl\u0151rinci \u00fati ltp.","Hat\u00e1r \u00fat M","Szentl\u0151rinci \u00fati lak\u00f3telep"],["54","LOV858","VanHool AG318 csukl\u00f3s aut\u00f3busz","BUS","P\u00e9terimajor, V\u00edztorony t\u00e9r","Bor\u00e1ros t\u00e9r H","K\u00e9n utca H (Illatos \u00fat)"],["136E","LOV864","VanHool AG318 csukl\u00f3s aut\u00f3busz","BUS","Havanna utcai lak\u00f3telep","K\u0151b\u00e1nya-Kispest M","\u00c1rp\u00e1d utca"],["23E","LOV865","VanHool AG318 csukl\u00f3s aut\u00f3busz","BUS","Bor\u00e1ros t\u00e9r H","Pesterzs\u00e9beti lak\u00f3telep","Bor\u00e1ros t\u00e9r H"],["123","LOV866","VanHool AG318 csukl\u00f3s aut\u00f3busz","BUS","Soroks\u00e1r, IKEA \u00e1ruh\u00e1z","Hat\u00e1r \u00fat M","Nagyk\u0151r\u00f6si \u00fat / Hat\u00e1r \u00fat"],["88","MRZ246","MAN A21 sz\u00f3l\u00f3 (Vol\u00e1n, helyi, 3 ajt\u00f3s)","BUS","Budat\u00e9t\u00e9ny v\u00e1. (Campona)","Kelenf\u00f6ld vas\u00fat\u00e1llom\u00e1s M","Tulip\u00e1n utca"],["40E","MRZ245","MAN A21 sz\u00f3l\u00f3 (Vol\u00e1n, helyi, 3 ajt\u00f3s)","BUS","Buda\u00f6rsi lak\u00f3 ...

# %% [markdown]
# ### Trips - so fat can only scrape active trips - worth re running the Vehicle script before

# %%
# %%time

time_epoch = str(int(time()))
today = date.today().strftime("%Y%m%d")

vehicles_link = 'https://futar.bkk.hu/api/query/v1/ws/otp/api/where/vehicles-for-location.json?ifModifiedSince=' + time_epoch + '&lat=' + lat + '&latSpan=1&lon=' + lon + '&lonSpan=1&key=bkk-web&version=4&appVersion=3.13.1-59506-4e2e9a7b'
sleep(2)
vehicles = get(vehicles_link, headers = headers).json()['data']

vehicles_rerun = vehicle_df_creator(vehicles)

trips_list = vehicles_rerun.drop_duplicates(['vehicleRouteType', 'shortName', 'From', 'To'])['tripId'].unique().tolist()
trips_list = [i for i in trips_list if isinstance(i, float) == False]
len(trips_list)
# Out:
# Wall time: 2.36 s
# 271

# %%
# %%time

trip_dicts = []

pool = Pool(4)

for i in trips_list:
    pool.apply_async(get_trip_details, (i,), callback = trip_dicts.append)

pool.close()
pool.join()
# Out:
# Wall time: 9.42 s

# %%
trips_df = pd.DataFrame([i for i in trip_dicts if i is not None])
trips_df.dropna(inplace = True)
print(trips_df.shape)
# Out:
# (269, 4)

# %%
trips_df = trips_df.merge(routes)
trips_df.head(3)
# Out:
#          id          tripId  num_of_stops  total_distance shortName  type  \
# 0  BKK_VP50   BKK_C37690370             7          3093.0        50   BUS
# 1  BKK_3020  BKK_C377832684            12          6055.0         2  TRAM
# 2  BKK_1231   BKK_C36950445            19          8117.0      123A   BUS
#
#                     From            To
# 0    Lajosmizsei sorompó    Határ út M
# 1        Jászai Mari tér  Közvágóhíd H
# 2  Szentlőrinci úti ltp.    Határ út M

# %%
boxplot_sns(trips_df, 'type', 'num_of_stops')

# %%
boxplot_sns(trips_df, 'type', 'total_distance')

# %% [markdown]
# Legkevesebb megálló

# %%
trips_df[trips_df['num_of_stops'] < 5].sort_values('num_of_stops', ascending = True)
# Out:
#             id          tripId  num_of_stops  total_distance shortName type  \
# 208   BKK_8902   BKK_C37523948             1          5688.0         B  BUS
# 205   BKK_8903   BKK_C37523298             2         22732.0         C  BUS
# 57    BKK_1005   BKK_C38109375             3         20377.0      100E  BUS
# 64    BKK_VP60    BKK_C3664175             3          1953.0        60  BUS
# 211   BKK_8905   BKK_C37523273             3          7372.0         E  BUS
# 10    BKK_2360   BKK_C18585133             4          2514.0       236  BUS
# 94    BKK_1650   BKK_C21515198             4          1412.0       165  BUS
# 207   BKK_8901   BKK_C37523139             4          5732.0         A  BUS
# 209   BKK_8904   BKK_C37523250             4          9271.0         D  BUS
# 216   BKK_1520  BKK_C350341051             4          2118.0       152  BUS
# 231  BKK_VP601    BKK_C3723727             4          4674.0       60A  BUS
#
#                          From                       To
# 208         Deák Ferenc tér M                 Expó tér
# 205           Airport - Monor       Budapest, Expó tér
# 57     Liszt Ferenc Airport 2        Deák Ferenc tér M
# 64             Széchenyi-hegy                 Svábhegy
# 211                  Vág utca                 Expó tér
# 10    Havanna utcai lakótelep  Market Central Ferihegy
# 94             Remetehegyi út               Kolosy tér
# 207  Stadion autóbusz-állomás                 Expó tér
# 209                Vigadó tér                 Expó tér
# 216               Hollandi út           Szent Imre tér
# 231        Szent János Kórház              Pethényi út

# %% [markdown]
# Legtöbb megálló

# %%
trips_df[trips_df['num_of_stops'] > 40].sort_values('num_of_stops', ascending = False)
# Out:
#            id          tripId  num_of_stops  total_distance shortName type  \
# 22   BKK_0880  BKK_C276418516            55         27781.0        88  BUS
# 135  BKK_1980   BKK_C35248438            48         20821.0       198  BUS
# 245  BKK_0460   BKK_C36913768            47         23723.0        46  BUS
# 140  BKK_0050  BKK_C355542037            44         18928.0         5  BUS
# 46   BKK_0360   BKK_C32693841            43         18660.0        36  BUS
#
#                             From                         To
# 22      Budatétény vá. (Campona)   Kelenföld vasútállomás M
# 135  R.csaba-Újtelep, Tóalmás u.   Dél-pesti autóbuszgarázs
# 245          Helikopter lakópark    Újpalota, Nyírpalota út
# 140    Rákospalota, Kossuth utca               Pasaréti tér
# 46          Csepel, Csillagtelep  Pestszentlőrinc vasútáll.

# %% [markdown]
# Legkisebb távolság

# %%
trips_df[trips_df['total_distance'] < 2000].sort_values('total_distance', ascending = True)
# Out:
#            id          tripId  num_of_stops  total_distance shortName type  \
# 94   BKK_1650   BKK_C21515198             4          1412.0       165  BUS
# 66   BKK_0161  BKK_C358804082             5          1417.0       16A  BUS
# 187  BKK_2970    BKK_C2479959             5          1841.0       297  BUS
# 64   BKK_VP60    BKK_C3664175             3          1953.0        60  BUS
#
#                From                         To
# 94   Remetehegyi út                 Kolosy tér
# 66         Dísz tér         Széll Kálmán tér M
# 187  Nyeremény utca  R.csaba-Újt. vasútállomás
# 64   Széchenyi-hegy                   Svábhegy

# %% [markdown]
# Legnagyobb távolság

# %%
trips_df[trips_df['total_distance'] > 20000].sort_values('total_distance', ascending = False)
# Out:
#            id           tripId  num_of_stops  total_distance shortName  \
# 127    BKK_H6  BKK_H202310_413            21         40115.0        H6
# 22   BKK_0880   BKK_C276418516            55         27781.0        88
# 17   BKK_1335    BKK_C36467945            38         26796.0      133E
# 245  BKK_0460    BKK_C36913768            47         23723.0        46
# 188  BKK_2240      BKK_C359649            36         23144.0       224
# 28     BKK_H8    BKK_H1036_333            18         23111.0        H8
# 205  BKK_8903    BKK_C37523298             2         22732.0         C
# 166  BKK_2960    BKK_B94521321            40         22480.0       296
# 34   BKK_1620    BKK_C35826640            39         20841.0       162
# 16     BKK_H5     BKK_H40933_3            17         20829.0        H5
# 135  BKK_1980    BKK_C35248438            48         20821.0       198
# 56   BKK_0085   BKK_C365511352            40         20726.0        8E
# 204  BKK_1400    BKK_C35441671            39         20695.0       140
# 57   BKK_1005    BKK_C38109375             3         20377.0      100E
#
#                  type                         From                         To
# 127  SUBURBAN_RAILWAY                      Ráckeve                 Közvágóhíd
# 22                BUS     Budatétény vá. (Campona)   Kelenföld vasútállomás M
# 17                BUS      Újpalota, Nyírpalota út   Nagytétény, Erdélyi utca
# 245               BUS          Helikopter lakópark    Újpalota, Nyírpalota út
# 188               BUS    Újpalota, Szentmihályi út  Újpalota, Szentmihályi út
# 28   SUBURBAN_RAILWAY                      Gödöllő             Örs vezér tere
# 205               BUS              Airport - Monor         Budapest, Expó tér
# 166               BUS      B.megyer, Újmegyeri tér  Újpalota, Szentmihályi út
# 34                BUS        Maglód, Auchan áruház     Kőbánya alsó vasútáll.
# 16   SUBURBAN_RAILWAY                   Szentendre              Batthyány tér
# 135               BUS  R.csaba-Újtelep, Tóalmás u.   Dél-pesti autóbuszgarázs
# 56                BUS      Újpalota, Nyírpalota út   Kelenföld vasútállomás M
# 204               BUS  Törökbálint, bevásárlóközp.         Széll Kálmán tér M
# 57                BUS       Liszt Ferenc Airport 2          Deák Ferenc tér M

# %%
# vehicles_df[vehicles_df['tripId'] == 'BKK_C175521046']

# %%
# trip_link = 'https://futar.bkk.hu/api/query/v1/ws/otp/api/where/trip-details.json?tripId=' + 'BKK_1634051485889' + '&date=' + today + '&key=bkk-web&version=4&appVersion=3.13.1-59506-4e2e9a7b&_=' + time_epoch
# get(trip_link, headers = headers).json()

# %% [markdown]
# ### Stop - todo

# %%
stop_id = 'BKK_F03326' # 45, Anilin --> Ors

stop_schedule_link = 'https://futar.bkk.hu/api/query/v1/ws/otp/api/where/schedule-for-stop.json?stopId=' + stop_id + '&key=bkk-web&version=4&appVersion=3.13.1-59506-4e2e9a7b&_=' + time_epoch
stop_vehicle_link = 'https://futar.bkk.hu/api/query/v1/ws/otp/api/where/vehicles-for-stop.json?stopId=' + stop_id + '&key=bkk-web&version=4&appVersion=3.13.1-59506-4e2e9a7b'
stop_route_link = 'https://futar.bkk.hu/api/query/v1/ws/otp/api/where/route-details-for-stop.json?stopId=' + stop_id + '&key=bkk-web&version=4&appVersion=3.13.1-59506-4e2e9a7b'
stop_arrivals_departures_link = 'https://futar.bkk.hu/api/query/v1/ws/otp/api/where/arrivals-and-departures-for-stop.json?includeReferences=agencies,routes,trips,stops&stopId=' + stop_id + '&minutesBefore=1&minutesAfter=30&key=bkk-web&version=4&appVersion=3.13.1-59506-4e2e9a7b&_=' + time_epoch

# %%
# stop_schedule = get(stop_schedule_link, headers = headers).json()['data']
# [{i['routeId'] : i['directions'][0]['stopTimes']} for i in stop_schedule['entry']['schedules']]

# %%
# pd.DataFrame(get(stop_vehicle_link, headers = headers).json()['data']['list'])

# %%
# pd.DataFrame(get(stop_route_link, headers = headers).json()['data']['list']) # NOT NEEDED

# %%
# get(stop_arrivals_departures_link, headers = headers).json()['data']['references']['trips']
